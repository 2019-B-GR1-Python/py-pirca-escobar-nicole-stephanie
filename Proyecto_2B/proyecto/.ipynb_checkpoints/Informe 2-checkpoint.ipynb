# %% [markdown]
# > # COMPARACIÓN DE PRECIOS EN MATERIAL TECNOLÓGICO ECUADOR
# > >> ## COMPUTRON VS POINT
# > ## Nicole Stephanie Pirca Escobar
# > ### Facultad de Ingeniería de Sistemas
# > ##### nicole.pirca@epn.edu.ec

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from IPython.display import display, HTML

# %%
path='C://Users//NICOLE//Documents//GitHub//py-pirca-escobar-nicole-stephanie//Proyecto_2B//proyecto//laptos//laptos.json'
df_lapto=pd.read_json(path)

# %%
df_lapto.head(20)
# Out:
#      categoria    empresa                                             nombre  \
# 0       Laptos  Computron  Laptop/Notebook Lenovo S145-15Ast Slim Amd A9-...
# 1       Laptos  Computron  Laptop/Notebook Hp Amd R5-2500U 2.0 Ghz-16Gb-1...
# 2       Laptos  Computron  LAPTOP/NOTEBOOK LENOVO IP330-14IKB CI3 7020U 2...
# 3       Laptos  Computron                Laptop/Notebook Hp Amd R5-2500U 2.0
# 4       Laptos  Computron        Laptop HP 14-CK0010LA | Intel Core i7-7020U
# 5       Laptos  Computron                           Laptop Lenovo S145-14IWL
# 6       Laptos  Computron         Laptop HP 14-CK0010LA  Intel Core i3-7020U
# 7       Laptos  Computron              Laptop HP 15-DB1022LA 3, 8GB, 1TB, 15
# 8       Laptos  Computron            Laptop HP 15-CM1002LA AMD Ryzen 5 3500U
# 9       Laptos  Computron  LAPTOP/NOTEBOOK LENOVO S145-14IGM SLIM CELERON...
# 10      Laptos  Computron                 LAPTOP/NOTEBOOK LENOVO IP330-14IKB
# 11      Laptos  Computron  Laptop/Notebook Hp Ci7 7500U 2.7Ghz-8Gb-1Tb-Tg...
# 12      Laptos  Computron    Laptop HP 15-DB1022LA AMD Ryzen 3, 8GB, 1TB, 15
# 13      Laptos  Computron                 Laptop DELL 5593 | Intel i7-1065G7
# 14      Laptos  Computron                   Laptop/Notebook Hp Envy X360 Amd
# 15      Laptos  Computron                  Laptop DELL 5593 | Intel i3-1015H
# 16      Laptos  Computron  Laptop/Notebook Hp Amd R5-2500U 2.0 Ghz-16Gb-1...
# 17      Laptos  Computron  Laptop/Notebook Hp Envy X360 Amd R5-2500U 2.0G...
# 18  Celularess  Computron  Laptop/Notebook Hp Amd R5-2500U 2.0 Ghz-16Gb-1...
# 19  Impresoras  Computron  Impresora Multifuncion Hp Color Ink 2135 Blanc...
#
#     precio_oferta  precio_regular
# 0          458.00          550.08
# 1          404.21          543.16
# 2          471.17          581.47
# 3          590.52          682.92
# 4          545.26          699.54
# 5          566.80          729.13
# 6          423.44          586.82
# 7          290.71          370.29
# 8          406.98          521.68
# 9          351.50          448.34
# 10         370.07          423.61
# 11         335.05          427.37
# 12         233.53          297.87
# 13         311.37          397.16
# 14         410.56          541.03
# 15         880.43          992.08
# 16         640.14          759.74
# 17         423.61          583.95
# 18         557.03          659.00
# 19         217.96          290.47

# %% [markdown]
# ### Productos Ofrecidos por Negocio

# %%
laptos_count = df_lapto['empresa'].value_counts()[:10].sort_values().plot(kind='barh')
plt.savefig('ventas.jpg')

# %% [markdown]
# ### Productos con mayor oferta

# %%
total_productos=df_lapto['categoria']=='Laptos'
df_lapto[total_productos].sort_values(by=['precio_regular'], ascending=False).head(10)
# Out:
#    categoria    empresa                                             nombre  \
# 15    Laptos  Computron                  Laptop DELL 5593 | Intel i3-1015H
# 16    Laptos  Computron  Laptop/Notebook Hp Amd R5-2500U 2.0 Ghz-16Gb-1...
# 5     Laptos  Computron                           Laptop Lenovo S145-14IWL
# 4     Laptos  Computron        Laptop HP 14-CK0010LA | Intel Core i7-7020U
# 3     Laptos  Computron                Laptop/Notebook Hp Amd R5-2500U 2.0
# 6     Laptos  Computron         Laptop HP 14-CK0010LA  Intel Core i3-7020U
# 17    Laptos  Computron  Laptop/Notebook Hp Envy X360 Amd R5-2500U 2.0G...
# 2     Laptos  Computron  LAPTOP/NOTEBOOK LENOVO IP330-14IKB CI3 7020U 2...
# 0     Laptos  Computron  Laptop/Notebook Lenovo S145-15Ast Slim Amd A9-...
# 1     Laptos  Computron  Laptop/Notebook Hp Amd R5-2500U 2.0 Ghz-16Gb-1...
#
#     precio_oferta  precio_regular
# 15         880.43          992.08
# 16         640.14          759.74
# 5          566.80          729.13
# 4          545.26          699.54
# 3          590.52          682.92
# 6          423.44          586.82
# 17         423.61          583.95
# 2          471.17          581.47
# 0          458.00          550.08
# 1          404.21          543.16

# %%
productos = sns.barplot(x='negocio', y='precio_oferta', data=df_lapto)
plt.savefig('Descuento por Negocio')

# %% [markdown]
# ### Televisores

# %%
Total_televisores=df_lapto['categoria']=='Televisores'
df_lapto[Total_televisores].sort_values(by=['precio_regular']).head(10)
# Out:
#        categoria    empresa  \
# 123  Televisores      Point
# 133  Televisores      Point
# 132  Televisores      Point
# 120  Televisores      Point
# 119  Televisores      Point
# 37   Televisores  Computron
# 36   Televisores  Computron
# 26   Televisores  Computron
# 135  Televisores      Point
# 134  Televisores      Point
#
#                                                 nombre  precio_oferta  \
# 123  Televisor-Tv Samsung 75  Led 4K Uhd Smart (2A)...          18.49
# 133      Televisor-Tv Samsung 55 Led 4K Uhd Smart (2A)          18.49
# 132      Televisor-Tv Samsung 85 Led 4K Uhd Smart (2A)          18.49
# 120              Televisor-Tv Samsung 55 Sidney Blanco          18.49
# 119                Televisor-Tv Samsung 55 Sidney Rojo          18.49
# 37       Televisor-Tv Samsung 55 - Soundbar Triangular          51.56
# 36      Televisor-Tv Samsung 45  Led 4K Uhd Smart (2A)          51.56
# 26                   Televisor-Tv Xtratech Wifi Isdb-T          54.93
# 135     Televisor-Tv Tcl 43 Led 4K Uhd Smart Wifi (1A)          78.99
# 134                                      Mesa Art Café          78.99
#
#      precio_regular
# 123           18.49
# 133           18.49
# 132           18.49
# 120           18.49
# 119           18.49
# 37            59.03
# 36            59.03
# 26            62.89
# 135           78.99
# 134           78.99

# %%
plt.title('Negocios por Categoria')
categoriaNegocio = df_lapto['categoria'].value_counts()[:].sort_values().plot(kind='barh')
count_categoriaNegocio = df_lapto['categoria'].value_counts()[:]
plt.savefig("negocioCategoria.jpg")
plt.show()

# %%
lista = df_lapto.sort_values('precio_oferta')

# %%
f, ax = plt.subplots(figsize=(15, 10))
ax = sns.regplot(x='precio_oferta', y='precio_regular',data=lista)
plt.show()

# %% [markdown]
# ### Celulares

# %%
scategoriaTelevisor=df_lapto['categoria']=='celulares'
df_lapto[scategoriaTelevisor].sort_values(by=['precio_regular']).head(15)
# Out:
#      categoria    empresa                                             nombre  \
# 108  celulares  Computron                   Celular Huawei Y5 2019 32Gb Gris
# 118  celulares      Point                     Celular Mtt M15D Gsm Bluetooth
# 117  celulares      Point                     Celular Mtt M14D Gsm Bluetooth
# 111  celulares      Point                 Celular Huawei Y5 2019 32Gb Blanco
# 110  celulares  Computron  Celular Xiaomi Redmi 8A. 2Gb 32Gb. Azul Agrega...
# 112  celulares      Point                          Celular Samsung J2 Core 5
# 107  celulares      Point  Celular Xiaomi Redmi 8A. 2Gb 32Gb. Blanco Agre...
# 105  celulares      Point                             Celular Samsung Galaxy
# 106  celulares  Computron                 Celular Huawei Y5 2019 32Gb Blanco
# 101  celulares  Computron                   Celular Huawei Y5 2019 32Gb Azul
# 116  celulares      Point                               Celular Samsung A20s
# 100  celulares      Point                         Celular Samsung Galaxy 6.1
# 99   celulares      Point                    Celular Samsung Galaxy A10S 6.2
# 95   celulares  Computron            Celular Samsung J2 Core 5 1Gb 8Gb Negro
# 115  celulares      Point                 Celular Huawei Y5 2019 32Gb Blanco
#
#      precio_oferta  precio_regular
# 108          24.89           24.89
# 118          35.00           35.00
# 117          35.00           35.00
# 111          98.99           98.99
# 110          98.99           98.99
# 112         108.99          108.99
# 107         108.99          108.99
# 105         119.00          119.00
# 106         128.99          128.99
# 101         148.99          148.99
# 116         169.98          169.98
# 100         189.00          189.00
# 99           98.99          198.99
# 95          198.99          198.99
# 115         198.99          198.99

# %%
plt.figure(figsize=(30,10))
ax = plt.gca()
plt.title("rating_count_tot vs rating_count_ver")
df_lapto.head(200).plot(kind='line',x='nombre',y='precio_oferta',ax=ax)
df_lapto.head(200).plot(kind='line',x='nombre',y='precio_regular', color='red', ax=ax)
plt.show()

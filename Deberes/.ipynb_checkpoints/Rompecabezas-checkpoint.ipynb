# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
mapache= misc.face()
mapache

# %%
plt.imshow(mapache)
plt.show

# %%
#todo rojo
mapache_red=np.copy(mapache)
mapache_red[:,:,1]=0
mapache_red[:,:,2]=0
plt.title("mapache canal rojo")
plt.imshow(mapache_red)

# %%
#Para hacer una inspección detallada de variaciones de intensidad podemos usar interpolation='nearest'
mapache_inspeccion=np.copy(mapache)
plt.imshow(mapache_inspeccion[100:800, 250:600], cmap=plt.cm.gray)
plt.imshow(mapache_inspeccion[100:800, 250:600], cmap=plt.cm.gray, interpolation='nearest')

# %%
plt.imshow(mapache[0:7])
plt.show

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
from scipy import misc

# %%
def rompecabezas():
    mapache = misc.face()
    print("Imagen Original")
    plt.imshow(mapache)
    plt.show()
    num_partes = input("Ingrese un numero par de division del tablero    ")
    mapache_partes_rompecabezas = np.vsplit(mapache,int(num_partes))
    piezas_num = np.random.permutation(int(num_partes))
    mapache_random = np.concatenate(list(map(lambda x: mapache_partes_rompecabezas[x],piezas_num)))
    print("Imagen Random Mapache")
    plt.imshow(mapache_random)
    plt.show()

rompecabezas()
# Out:
# Imagen Original
# Ingrese un numero par de division del tablero    4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-86dc1244b240> in <module>
#      12     plt.show()
#      13
# ---> 14 rompecabezas()
#      15
#
# <ipython-input-6-86dc1244b240> in rompecabezas()
#       7     mapache_partes_rompecabezas = np.vsplit(mapache,int(num_partes))
#       8     piezas_num = np.random.permutation(int(num_partes))
# ----> 9     mapache_random = np.concatenate(list(map(lambda x: mapache_partes_rompecabezas[x],piezasI)))
#      10     print("Imagen Random Mapache")
#      11     plt.imshow(mapache_random)
#
# NameError: name 'piezasI' is not defined

# %%
def menu_principal ():
    print ("Selecciona una opción")
    print ("\t1 - JUGAR")
    print ("\t2 - SALIR")
       
while True:
    menu_principal()
    opcionMenu = input("Elija una opción ")
    if opcionMenu =="1":
        print("STAR GAME")
        rompecabezas()
        print("STAR GAME")
        posicion_old = input("Posicion Imagen a mover: ")
        posicion_new = input("Nueva Posicion a mover: ")
        aux = piezas_num[int(posicion_old)]
        piezas_num[int(posicion_old)] = piezas_num[int(posicion_new)]
        piezasI[int(posicion_new)] = aux
        
        mapache_randomt = np.concatenate(list(map(lambda x: mapache_partes_rompecabezas[x],piezas_num)))
        plt.imshow(mapache_randomt)
        plt.show()
    elif opcionMenu =="2":
        print("GAME OVER")
        break
        
        
        
def moverPiezas():
        posicion_old = input("Posicion Imagen a mover: ")
        posicion_new = input("Nueva Posicion a mover: ")
        aux = piezasI[int(posicion_old)]
        piezasI[int(posicion_old)] = piezasI[int(posicion_new)]
        piezasI[int(posicion_new)] = aux
        
        mapache_randomt = np.concatenate(list(map(lambda x: mapache_partes_rompecabezas[x],piezasI)))
        plt.imshow(mapache_randomt)
        plt.show()
        
        
def rompecabezas():
    mapache = misc.face()
    print("Imagen Original")
    plt.imshow(mapache)
    plt.show()
    num_partes = input("Ingrese un numero dimenciones par de division del tablero    ")
    mapache_partes_rompecabezas = np.vsplit(mapache,int(num_partes))
    piezasI = np.random.permutation(int(num_partes))
    mapache_random = np.concatenate(list(map(lambda x: mapache_partes_rompecabezas[x],piezasI)))
    print("Imagen Random Mapache")
    plt.imshow(mapache_random)
    plt.show()
# Out:
# Selecciona una opción
# 	1 - JUGAR
# 	2 - SALIR
# Elija una opción 1
# STAR GAME
# Imagen Original
# Ingrese un numero par de division del tablero    4
# Imagen Random Mapache
# STAR GAME
# Posicion Imagen a mover: 1
# Nueva Posicion a mover: 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f50b350e2ca1> in <module>
#      13         posicion_old = input("Posicion Imagen a mover: ")
#      14         posicion_new = input("Nueva Posicion a mover: ")
# ---> 15         aux = piezasI[int(posicion_old)]
#      16         piezasI[int(posicion_old)] = piezasI[int(posicion_new)]
#      17         piezasI[int(posicion_new)] = aux
#
# NameError: name 'piezasI' is not defined

# %%
def moverPiezas():
        posicion_old = input("Posicion Imagen a mover: ")
        posicion_new = input("Nueva Posicion a mover: ")
        aux = piezasI[int(posicion_old)]
        piezasI[int(posicion_old)] = piezasI[int(posicion_new)]
        piezasI[int(posicion_new)] = aux
        
        mapache_randomt = np.concatenate(list(map(lambda x: mapache_partes_rompecabezas[x],piezasI)))
        plt.imshow(mapache_randomt)
        plt.show()
moverPiezas()
# Out:
# Posicion Imagen a mover: 2
# Nueva Posicion a mover: 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c4958fc4752f> in <module>
#       9         plt.imshow(mapache_randomt)
#      10         plt.show()
# ---> 11 moverPiezas()
#
# <ipython-input-5-c4958fc4752f> in moverPiezas()
#       2         posicion_old = input("Posicion Imagen a mover: ")
#       3         posicion_new = input("Nueva Posicion a mover: ")
# ----> 4         aux = piezasI[int(posicion_old)]
#       5         piezasI[int(posicion_old)] = piezasI[int(posicion_new)]
#       6         piezasI[int(posicion_new)] = aux
#
# NameError: name 'piezasI' is not defined

# %%
        mover_posicion_a = input("Ficha a mover: ")
        mover_posicion_b = input("Posicion a mover: ")
        pieza_temporal = piezas_index[int(mover_posicion_a)]
        piezas_index[int(mover_posicion_a)] = piezas_index[int(mover_posicion_b)]
        piezas_index[int(mover_posicion_b)] = pieza_temporal
        
        mapache_desordenado = np.concatenate(list(map(lambda x: mapache_parts[x],piezas_index)))
        plt.imshow(mapache_desordenado)
        plt.show()

# %%
def menu_principal ():
    print ("Selecciona una opción")
    print ("\t1 - Ingresar Modelos")
    print ("\t2 - Eliminar Modelo Registrado")
    print ("\t3 - Consultar Modelos Registrados")
    print ("\t4 - Modificar Modelos Registrados")
    print ("\t5 - salir")

while True:
    menu_principal()
      
    opcionMenu = input("inserta un numero valor >> ")
            
    if opcionMenu=="1":
        print("Has pulsado la opción 1...\Registros de Modelos")
        nuevo_Modelo = Modelo("","","","")
     
    elif opcionMenu=="2": 
        
        print("opción 2...\n Eliminar Modelo registrado \n pulsa una tecla para continuar")
        eliminar_modelo()
        
    elif opcionMenu=="3":
        print("opción 3...\nConsultar Modelos Registrados \n pulsa una tecla para continuar")
        consulta_Modelo()
        
    elif opcionMenu=="4":
        print("opción 4...\nModificar Modelos Registrados \n pulsa una tecla para continuar")
        modificar_Modelo()
   
    elif opcionMenu=="5":
        break
    else:
        input("No has pulsado ninguna opción correcta...\npulsa una tecla para continuar")


class Modelo:
    
    nombre=""
    color=""
    caracteristica=""
    precio=""
    path='./modelo.txt'
       
    def __init__(self,nombre,color,caracteristica,precio):  
        path='./modelo.txt'
        archivo_escritura_abierto = open(path, mode="a")
        print("Nombre del Modelo: ")
        nom_Modelo=input(self.nombre) 
        self.nombre = nombre
                
        print("Color del Modelo: ")
        col_Modelo=input(self.color) 
        self.color = color
                
        print("Caracteristicas del Modelo: ")
        carac_Modelo=input(self.caracteristica) 
        self.caracteristica = caracteristica
                
        print("Precio del Modelo: ")
        precio_Modelo=input(self.precio) 
        self.precio = precio
        archivo_escritura_abierto.writelines([nom_Modelo,"\n",col_Modelo,"\n",carac_Modelo,"\n",precio_Modelo])
        
        print("REGISTRO INGRESADO CON EXITO")

def consulta_Modelo():
    try:
        path = './modelo.txt'
        archivo_abierto = open(path)
        contenido = archivo_abierto.readlines() 
        
        for linea in contenido:
            print(linea)

    except Exception as error:
        print("Error")
        
        
def modificar_Modelo():
    path='./modelo.txt'
    archivo_escritura_abierto = open(path)
    contenido = archivo_escritura_abierto.readlines()
    archivo_escritura_abierto.close()
    archivo_escritura_abierto = open(path,mode="w")
    for linea in contenido:
        print(linea)
    linea_eliminar = input("Ingrese los datos del modelo Auto a modificar: ")
    linea_agregar = input("Ingrese los datos del modelo Auto modificado: ")
    for linea in contenido:
        if linea != "{linea_eliminar}"
           archivo_escritura_abierto.write("{linea}")
        else:
        archivo_escritura_abierto.write("{linea_agregar}")
        archivo_escritura_abierto.close()
    except Exception as error:
         print('error')

            
def eliminar_modelo():
    try:
        path = './modelo.txt'
        archivo_escritura_abierto = open(path)
        contenido =archivo_escritura_abierto.readlines()
        archivo_escritura_abierto.close()
        archivo_escritura_abierto = open(path,mode="w")
           for linea in contenido:
                print(linea),
                linea_eliminar = input("Ingrese los datos del modelo auto a eliminar:")
                for linea in contenido:
                        if linea != "{linea_eliminar}"
                        archivo_escritura_abierto.write("{linea}")
                        archivo_escritura_abierto.close()
                    except Exception as error:
                        else:
                        print('error No existe')
# Out:
# Selecciona una opción
# 	1 - Ingresar Modelos
# 	2 - Eliminar Modelo Registrado
# 	3 - Consultar Modelos Registrados
# 	4 - salir
# inserta un numero valor >> 3
# opción 3...
# Consultar Modelos Registrados
#  pulsa una tecla para continuar
# 1. KIA
#
# AZUL
#
# Contorno Redondo
#
# 25000
# Selecciona una opción
# 	1 - Ingresar Modelos
# 	2 - Eliminar Modelo Registrado
# 	3 - Consultar Modelos Registrados
# 	4 - salir
